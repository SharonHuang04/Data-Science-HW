# %%
import pandas as pd
df_shroom = pd.read_csv('mushrooms.csv')
df_shroom
# Out:
#           class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     poisonous         x           s         n       t    p               f
# 1        edible         x           s         y       t    a               f
# 2        edible         b           s         w       t    l               f
# 3     poisonous         x           y         w       t    p               f
# 4        edible         x           s         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8119     edible         k           s         n       f    n               a
# 8120     edible         x           s         n       f    n               a
# 8121     edible         f           s         n       f    n               a
# 8122  poisonous         k           y         n       f    y               f
# 8123     edible         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
import numpy as np
import math
def entropy(probs):
    ### take a list of probabilities and calculate their entropy values
    
    # your code here
    list_entropy=0
    # 帶entropy計算公式
    for i in probs.keys():
        if probs[i]>0:
            list_entropy-=probs[i]*math.log(probs[i],2)  #log以2為底
    
    return list_entropy
    

def entropy_of_list(a_list):
    ### take a list of items with discrete values (e.g., poisonous, edible)
    ### and return the list of entropy values for those items
    
    # your code here
    counts={}
    #計算poisonous，edible次數
    for i in range(len(a_list)):   #遍歷a_list
        if a_list[i] not in counts:  #若a_list的元素沒有在counts裡面出現過，新增進字典裡
            counts[a_list[i]]=0
        counts[a_list[i]]+=1
    probs={}
    for key in counts:
        probs[key]=counts[key]/len(a_list)  #算出機率
    
    return entropy(probs)
    
# the initial entropy of the poisonous/edible column for all instances in the dataset
total_entropy = entropy_of_list(df_shroom['class'])
print(total_entropy)
# Out:
# 0.9990678968724604

# %%
def information_gain(df, split_feature_name, target_feature_name):
    
    ### take a dataFrame of features, and quantify the entropy of a target feature
    ### after performing a split along the values of another feature
    ### and calculate the corresponding information gain

    # your code here
    # 計算原始entropy
    original_entropy = entropy_of_list(df[target_feature_name])
    #要分的特徵有哪些值
    uniquevalues = df[split_feature_name].unique() 
    #那些值各自出現的次數
    valueCounts=df[split_feature_name].value_counts()
    #特徵的總entropy
    total_entropy=0
    for value in uniquevalues:
        # 各自出現的機率
        probability=valueCounts[value]/len(df[split_feature_name])
        target_list=[]
        # 根據 value 拆開資料庫
        for i in range(len(df[split_feature_name])):
            if df.iloc[i][split_feature_name]==value:
                target_list.append(df.iloc[i][0])
        # 計算 entropy
        entropy=entropy_of_list(target_list)
        total_entropy+=probability*entropy
    info_gain=original_entropy-total_entropy
    
    return info_gain

print('\nExample: information gain for the best feature is ' + str(information_gain(df_shroom, 'odor', 'class')))
# Out:
# Example: information gain for the best feature is 0.9060749773839998

# %%
def id3(df, target_feature_name, feature_names, default_class = None):
    
    ## counting for the target feature
    from collections import Counter
    cnt = Counter(x for x in df[target_feature_name])
    
    ## First check: do instances in this split of the dataset belong to the same class?
    # (i.e., all mushrooms in this set are poisonous)
    # if yes, return that homogenous label (e.g., 'poisonous')
    if len(cnt) == 1:
        return list(cnt.keys())[0]
    
    ## Second check: is this split of the dataset empty?
    # if yes, return a default value
    elif df.empty or (not feature_names):
        return default_class 
    
    ## Otherwise: this dataset is ready to be split!
    else:
        ### step 1: get the default value for next recursive call of this function
        index_of_max = list(cnt.values()).index(max(cnt.values())) 
        default_class = list(cnt.keys())[index_of_max] # most common value of target feature in dataset
        
        ### step 2: choose the best feature to split on
        
        # your code here
        # 計算所有特徵的 info_gains
        info_gains = [information_gain(df, x, target_feature_name) for x in feature_names]
        best_feature_index = info_gains.index(max(info_gains))
        # 找info_gains最大的為最優特徵
        best_feature = feature_names[best_feature_index]

        ### step 3: create an empty tree, to be populated in a moment
        
        # your code here
        
        tree = {}
        # 現在的最優特徵
        tree[best_feature] = {}

        
        ### Step 4: split dataset
        # on each split, recursively call this "id3" function
        # populate the empty tree with subtrees, which
        # are the result of the recursive call
        
        # your code here
        
        # 開始拆資料庫
        uniqueValues = df[best_feature].unique()
        # 扣除最優特徵
        feature_names.remove(best_feature)
        # 建立子tree
        for value in uniqueValues:
            new_df = df[df[best_feature] == value]
            tree[best_feature][value] = id3(new_df, 'class', feature_names, default_class)     
        return tree

# %%
# get feature names (all but 'class' column)
feature_names = list(df_shroom.columns)
feature_names.remove('class')
# visualize the constructed decision tree using pprint package
from pprint import pprint
# use all instances (df_shroom) to build the decision (suppose all instances are for training)
tree = id3(df_shroom, 'class', feature_names)
pprint(tree)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-57f889cd394b> in <module>
#       5 from pprint import pprint
#       6 # use all instances (df_shroom) to build the decision (suppose all instances are for training)
# ----> 7 tree = id3(df_shroom, 'class', feature_names)
#       8 pprint(tree)
#
# <ipython-input-6-4d8ff1972d55> in id3(df, target_feature_name, feature_names, default_class)
#      54         for value in uniqueValues:
#      55             new_df = df[df[best_feature] == value]
# ---> 56             tree[best_feature][value] = id3(new_df, 'class', feature_names, default_class)
#      57         return tree
#
# <ipython-input-6-4d8ff1972d55> in id3(df, target_feature_name, feature_names, default_class)
#      26         # your code here
#      27         # 計算所有特徵的 info_gains
# ---> 28         info_gains = [information_gain(df, x, target_feature_name) for x in feature_names]
#      29         best_feature_index = info_gains.index(max(info_gains))
#      30         # 找info_gains最大的為最優特徵
#
# <ipython-input-6-4d8ff1972d55> in <listcomp>(.0)
#      26         # your code here
#      27         # 計算所有特徵的 info_gains
# ---> 28         info_gains = [information_gain(df, x, target_feature_name) for x in feature_names]
#      29         best_feature_index = info_gains.index(max(info_gains))
#      30         # 找info_gains最大的為最優特徵
#
# <ipython-input-5-c41cff174e68> in information_gain(df, split_feature_name, target_feature_name)
#       7     # your code here
#       8     # 計算原始entropy
# ----> 9     original_entropy = entropy_of_list(df[target_feature_name])
#      10     #要分的特徵有哪些值
#      11     uniquevalues = df[split_feature_name].unique()
#
# <ipython-input-2-16e261bd672a> in entropy_of_list(a_list)
#      22     #計算poisonous，edible次數
#      23     for i in range(len(a_list)):   #遍歷a_list
# ---> 24         if a_list[i] not in counts:  #若a_list的元素沒有在counts裡面出現過，新增進字典裡
#      25             counts[a_list[i]]=0
#      26         counts[a_list[i]]+=1
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 0
